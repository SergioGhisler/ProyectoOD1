# %% [markdown]
#  # <div align="center">Flying Pigs</div>
#  ### <div align="center"> House Prices: Advanced Regression Techniques </div>
# <img src="http://s9.picofile.com/file/8338980150/House_price.png"></img>

# %% [markdown]
#  # <div align="center">1. Inicialización</div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
train=pd.read_csv('train.csv')
train
# Out:
#         Id  Clasificación Zona  Ancho de calle  Pies cuadrados terreno  \
# 0        1             60   RL            65.0                    8450
# 1        2             20   RL            80.0                    9600
# 2        3             60   RL            68.0                   11250
# 3        4             70   RL            60.0                    9550
# 4        5             60   RL            84.0                   14260
# 5        6             50   RL            85.0                   14115
# 6        7             20   RL            75.0                   10084
# 7        8             60   RL             NaN                   10382
# 8        9             50   RM            51.0                    6120
# 9       10            190   RL            50.0                    7420
# 10      11             20   RL            70.0                   11200
# 11      12             60   RL            85.0                   11924
# 12      13             20   RL             NaN                   12968
# 13      14             20   RL            91.0                   10652
# 14      15             20   RL             NaN                   10920
# 15      16             45   RM            51.0                    6120
# 16      17             20   RL             NaN                   11241
# 17      18             90   RL            72.0                   10791
# 18      19             20   RL            66.0                   13695
# 19      20             20   RL            70.0                    7560
# 20      21             60   RL           101.0                   14215
# 21      22             45   RM            57.0                    7449
# 22      23             20   RL            75.0                    9742
# 23      24            120   RM            44.0                    4224
# 24      25             20   RL             NaN                    8246
# 25      26             20   RL           110.0                   14230
# 26      27             20   RL            60.0                    7200
# 27      28             20   RL            98.0                   11478
# 28      29             20   RL            47.0                   16321
# 29      30             30   RM            60.0                    6324
# ...    ...            ...  ...             ...                     ...
# 1430  1431             60   RL            60.0                   21930
# 1431  1432            120   RL             NaN                    4928
# 1432  1433             30   RL            60.0                   10800
# 1433  1434             60   RL            93.0                   10261
# 1434  1435             20   RL            80.0                   17400
# 1435  1436             20   RL            80.0                    8400
# 1436  1437             20   RL            60.0                    9000
# 1437  1438             20   RL            96.0                   12444
# 1438  1439             20   RM            90.0                    7407
# 1439  1440             60   RL            80.0                   11584
# 1440  1441             70   RL            79.0                   11526
# 1441  1442            120   RM             NaN                    4426
# 1442  1443             60   FV            85.0                   11003
# 1443  1444             30   RL             NaN                    8854
# 1444  1445             20   RL            63.0                    8500
# 1445  1446             85   RL            70.0                    8400
# 1446  1447             20   RL             NaN                   26142
# 1447  1448             60   RL            80.0                   10000
# 1448  1449             50   RL            70.0                   11767
# 1449  1450            180   RM            21.0                    1533
# 1450  1451             90   RL            60.0                    9000
# 1451  1452             20   RL            78.0                    9262
# 1452  1453            180   RM            35.0                    3675
# 1453  1454             20   RL            90.0                   17217
# 1454  1455             20   FV            62.0                    7500
# 1455  1456             60   RL            62.0                    7917
# 1456  1457             20   RL            85.0                   13175
# 1457  1458             70   RL            66.0                    9042
# 1458  1459             20   RL            68.0                    9717
# 1459  1460             20   RL            75.0                    9937
#
#      Pavimento Callejón Relieve Geografía del terreno Utilidades  \
# 0         Pave      NaN     Reg                   Lvl     AllPub
# 1         Pave      NaN     Reg                   Lvl     AllPub
# 2         Pave      NaN     IR1                   Lvl     AllPub
# 3         Pave      NaN     IR1                   Lvl     AllPub
# 4         Pave      NaN     IR1                   Lvl     AllPub
# 5         Pave      NaN     IR1                   Lvl     AllPub
# 6         Pave      NaN     Reg                   Lvl     AllPub
# 7         Pave      NaN     IR1                   Lvl     AllPub
# 8         Pave      NaN     Reg                   Lvl     AllPub
# 9         Pave      NaN     Reg                   Lvl     AllPub
# 10        Pave      NaN     Reg                   Lvl     AllPub
# 11        Pave      NaN     IR1                   Lvl     AllPub
# 12        Pave      NaN     IR2                   Lvl     AllPub
# 13        Pave      NaN     IR1                   Lvl     AllPub
# 14        Pave      NaN     IR1                   Lvl     AllPub
# 15        Pave      NaN     Reg                   Lvl     AllPub
# 16        Pave      NaN     IR1                   Lvl     AllPub
# 17        Pave      NaN     Reg                   Lvl     AllPub
# 18        Pave      NaN     Reg                   Lvl     AllPub
# 19        Pave      NaN     Reg                   Lvl     AllPub
# 20        Pave      NaN     IR1                   Lvl     AllPub
# 21        Pave     Grvl     Reg                   Bnk     AllPub
# 22        Pave      NaN     Reg                   Lvl     AllPub
# 23        Pave      NaN     Reg                   Lvl     AllPub
# 24        Pave      NaN     IR1                   Lvl     AllPub
# 25        Pave      NaN     Reg                   Lvl     AllPub
# 26        Pave      NaN     Reg                   Lvl     AllPub
# 27        Pave      NaN     Reg                   Lvl     AllPub
# 28        Pave      NaN     IR1                   Lvl     AllPub
# 29        Pave      NaN     IR1                   Lvl     AllPub
# ...        ...      ...     ...                   ...        ...
# 1430      Pave      NaN     IR3                   Lvl     AllPub
# 1431      Pave      NaN     IR1                   Lvl     AllPub
# 1432      Pave     Grvl     Reg                   Lvl     AllPub
# 1433      Pave      NaN     IR1                   Lvl     AllPub
# 1434      Pave      NaN     Reg                   Low     AllPub
# 1435      Pave      NaN     Reg                   Lvl     AllPub
# 1436      Pave      NaN     Reg                   Lvl     AllPub
# 1437      Pave      NaN     Reg                   Lvl     AllPub
# 1438      Pave      NaN     Reg                   Lvl     AllPub
# 1439      Pave      NaN     Reg                   Lvl     AllPub
# 1440      Pave      NaN     IR1                   Bnk     AllPub
# 1441      Pave      NaN     Reg                   Lvl     AllPub
# 1442      Pave      NaN     Reg                   Lvl     AllPub
# 1443      Pave      NaN     Reg                   Lvl     AllPub
# 1444      Pave      NaN     Reg                   Lvl     AllPub
# 1445      Pave      NaN     Reg                   Lvl     AllPub
# 1446      Pave      NaN     IR1                   Lvl     AllPub
# 1447      Pave      NaN     Reg                   Lvl     AllPub
# 1448      Pave      NaN     Reg                   Lvl     AllPub
# 1449      Pave      NaN     Reg                   Lvl     AllPub
# 1450      Pave      NaN     Reg                   Lvl     AllPub
# 1451      Pave      NaN     Reg                   Lvl     AllPub
# 1452      Pave      NaN     Reg                   Lvl     AllPub
# 1453      Pave      NaN     Reg                   Lvl     AllPub
# 1454      Pave     Pave     Reg                   Lvl     AllPub
# 1455      Pave      NaN     Reg                   Lvl     AllPub
# 1456      Pave      NaN     Reg                   Lvl     AllPub
# 1457      Pave      NaN     Reg                   Lvl     AllPub
# 1458      Pave      NaN     Reg                   Lvl     AllPub
# 1459      Pave      NaN     Reg                   Lvl     AllPub
#
#           ...       Pies cuadr. piscina Calidad y condición piscina  Valla  \
# 0         ...                         0                         NaN    NaN
# 1         ...                         0                         NaN    NaN
# 2         ...                         0                         NaN    NaN
# 3         ...                         0                         NaN    NaN
# 4         ...                         0                         NaN    NaN
# 5         ...                         0                         NaN  MnPrv
# 6         ...                         0                         NaN    NaN
# 7         ...                         0                         NaN    NaN
# 8         ...                         0                         NaN    NaN
# 9         ...                         0                         NaN    NaN
# 10        ...                         0                         NaN    NaN
# 11        ...                         0                         NaN    NaN
# 12        ...                         0                         NaN    NaN
# 13        ...                         0                         NaN    NaN
# 14        ...                         0                         NaN   GdWo
# 15        ...                         0                         NaN  GdPrv
# 16        ...                         0                         NaN    NaN
# 17        ...                         0                         NaN    NaN
# 18        ...                         0                         NaN    NaN
# 19        ...                         0                         NaN  MnPrv
# 20        ...                         0                         NaN    NaN
# 21        ...                         0                         NaN  GdPrv
# 22        ...                         0                         NaN    NaN
# 23        ...                         0                         NaN    NaN
# 24        ...                         0                         NaN  MnPrv
# 25        ...                         0                         NaN    NaN
# 26        ...                         0                         NaN    NaN
# 27        ...                         0                         NaN    NaN
# 28        ...                         0                         NaN    NaN
# 29        ...                         0                         NaN    NaN
# ...       ...                       ...                         ...    ...
# 1430      ...                         0                         NaN    NaN
# 1431      ...                         0                         NaN    NaN
# 1432      ...                         0                         NaN    NaN
# 1433      ...                         0                         NaN    NaN
# 1434      ...                         0                         NaN    NaN
# 1435      ...                         0                         NaN  GdPrv
# 1436      ...                         0                         NaN   GdWo
# 1437      ...                         0                         NaN    NaN
# 1438      ...                         0                         NaN  MnPrv
# 1439      ...                         0                         NaN    NaN
# 1440      ...                         0                         NaN    NaN
# 1441      ...                         0                         NaN    NaN
# 1442      ...                         0                         NaN    NaN
# 1443      ...                         0                         NaN    NaN
# 1444      ...                         0                         NaN    NaN
# 1445      ...                         0                         NaN    NaN
# 1446      ...                         0                         NaN    NaN
# 1447      ...                         0                         NaN    NaN
# 1448      ...                         0                         NaN   GdWo
# 1449      ...                         0                         NaN    NaN
# 1450      ...                         0                         NaN    NaN
# 1451      ...                         0                         NaN    NaN
# 1452      ...                         0                         NaN    NaN
# 1453      ...                         0                         NaN    NaN
# 1454      ...                         0                         NaN    NaN
# 1455      ...                         0                         NaN    NaN
# 1456      ...                         0                         NaN  MnPrv
# 1457      ...                         0                         NaN  GdPrv
# 1458      ...                         0                         NaN    NaN
# 1459      ...                         0                         NaN    NaN
#
#      Otras características Valor otras caract. Precio mensual Precio anual  \
# 0                      NaN                   0              2         2008
# 1                      NaN                   0              5         2007
# 2                      NaN                   0              9         2008
# 3                      NaN                   0              2         2006
# 1444  2905             20      NaN           125.0                   31250
# 1445  2906             90       RM            78.0                    7020
# 1446  2907            160       RM            41.0                    2665
# 1447  2908             20       RL            58.0                   10172
# 1448  2909             90       RL             NaN                   11836
# 1449  2910            180       RM            21.0                    1470
# 1450  2911            160       RM            21.0                    1484
# 1451  2912             20       RL            80.0                   13384
# 1452  2913            160       RM            21.0                    1533
# 1453  2914            160       RM            21.0                    1526
# 1454  2915            160       RM            21.0                    1936
# 1455  2916            160       RM            21.0                    1894
# 1456  2917             20       RL           160.0                   20000
# 1457  2918             85       RL            62.0                   10441
# 1458  2919             60       RL            74.0                    9627
#
#      Pavimento Callejón Relieve Geografía del terreno Utilidades  \
# 0         Pave      NaN     Reg                   Lvl     AllPub
# 1         Pave      NaN     IR1                   Lvl     AllPub
# 2         Pave      NaN     IR1                   Lvl     AllPub
# 3         Pave      NaN     IR1                   Lvl     AllPub
# 4         Pave      NaN     IR1                   HLS     AllPub
# 5         Pave      NaN     IR1                   Lvl     AllPub
# 6         Pave      NaN     IR1                   Lvl     AllPub
# 7         Pave      NaN     IR1                   Lvl     AllPub
# 8         Pave      NaN     Reg                   Lvl     AllPub
# 9         Pave      NaN     Reg                   Lvl     AllPub
# 10        Pave      NaN     IR1                   Lvl     AllPub
# 11        Pave      NaN     Reg                   Lvl     AllPub
# 12        Pave      NaN     Reg                   Lvl     AllPub
# 13        Pave      NaN     Reg                   Lvl     AllPub
# 14        Pave      NaN     Reg                   Lvl     AllPub
# 15        Pave      NaN     IR1                   Lvl     AllPub
# 16        Pave      NaN     IR1                   Lvl     AllPub
# 17        Pave      NaN     Reg                   Lvl     AllPub
# 18        Pave      NaN     IR1                   Lvl     AllPub
# 19        Pave      NaN     Reg                   HLS     AllPub
# 20        Pave      NaN     Reg                   Lvl     AllPub
# 21        Pave      NaN     IR1                   Lvl     AllPub
# 22        Pave      NaN     IR1                   Lvl     AllPub
# 23        Pave      NaN     Reg                   Lvl     AllPub
# 24        Pave      NaN     IR1                   Lvl     AllPub
# 25        Pave      NaN     IR1                   Lvl     AllPub
# 26        Pave      NaN     IR2                   Lvl     AllPub
# 27        Pave      NaN     Reg                   Lvl     AllPub
# 28        Pave      NaN     Reg                   Lvl     AllPub
# 29        Pave      NaN     Reg                   Lvl     AllPub
# ...        ...      ...     ...                   ...        ...
# 1429      Pave      NaN     Reg                   Lvl     AllPub
# 1430      Pave      NaN     Reg                   Lvl     AllPub
# 1431      Pave      NaN     Reg                   Lvl     AllPub
# 1432      Pave      NaN     Reg                   Lvl     AllPub
# 1433      Grvl      NaN     Reg                   Bnk     AllPub
# 1434      Pave      NaN     IR1                   HLS     AllPub
# 1435      Pave      NaN     IR1                   HLS     AllPub
# 1436      Pave      NaN     IR1                   Lvl     AllPub
# 1437      Pave      NaN     Reg                   Lvl     AllPub
# 1438      Pave      NaN     Reg                   Lvl     AllPub
# 1439      Pave      NaN     Reg                   Lvl     AllPub
# 4                            NaN    NaN                   NaN
# 5                            NaN    NaN                   NaN
# 6                            NaN  GdPrv                  Shed
# 7                            NaN    NaN                   NaN
# 8                            NaN    NaN                   NaN
# 9                            NaN  MnPrv                   NaN
# 10                           NaN    NaN                   NaN
# 11                           NaN    NaN                   NaN
# 12                           NaN    NaN                   NaN
# 13                           NaN    NaN                   NaN
# 14                           NaN    NaN                   NaN
# 15                           NaN    NaN                   NaN
# 16                           NaN    NaN                   NaN
# 17                           NaN    NaN                   NaN
# 18                           NaN    NaN                   NaN
# 19                           NaN    NaN                   NaN
# 20                           NaN    NaN                   NaN
# 21                           NaN    NaN                   NaN
# 22                           NaN    NaN                   NaN
# 23                           NaN    NaN                   NaN
# 24                           NaN    NaN                   NaN
# 25                           NaN    NaN                   NaN
# 26                           NaN    NaN                   NaN
# 27                           NaN    NaN                   NaN
# 28                           NaN    NaN                   NaN
# 29                           NaN    NaN                   NaN
# ...                          ...    ...                   ...
# 1429                         NaN  MnPrv                   NaN
# 1430                         NaN    NaN                   NaN
# 1431                         NaN    NaN                   NaN
# 1432                         NaN    NaN                   NaN
# 1433                         NaN    NaN                   NaN
# 1434                         NaN    NaN                   NaN
# 1435                         NaN    NaN                   NaN
# 1436                         NaN    NaN                   NaN
# 1437                         NaN    NaN                   NaN
# 1438                         NaN    NaN                   NaN
# 1439                         NaN    NaN                   NaN
# 1440                         NaN    NaN                   NaN
# 1441                         NaN    NaN                   NaN
# 1442                         NaN    NaN                   NaN
# 1443                         NaN    NaN                   NaN
# 1444                         NaN    NaN                   NaN
# 1445                         NaN    NaN                   NaN
# 1446                         NaN    NaN                   NaN
# 1447                         NaN    NaN                   NaN
# 1448                         NaN    NaN                   NaN
# 1449                         NaN    NaN                   NaN
# 1450                         NaN    NaN                   NaN
# 1451                         NaN    NaN                   NaN
# 1452                         NaN    NaN                   NaN
# 1453                         NaN  GdPrv                   NaN
# 1454                         NaN    NaN                   NaN
# 1455                         NaN    NaN                   NaN
# 1456                         NaN    NaN                   NaN
# 1457                         NaN  MnPrv                  Shed
# 1458                         NaN    NaN                   NaN
#
#      Valor otras caract. Precio mensual  Precio anual  Tipo de venta  \
# 0                      0              6          2010             WD
# 1                  12500              6          2010             WD
# 2                      0              3          2010             WD
# 3                      0              6          2010             WD
# 4                      0              1          2010             WD
# 5                      0              4          2010             WD
# 6                    500              3          2010             WD
# 7                      0              5          2010             WD
# 8                      0              2          2010             WD
# 9                      0              4          2010             WD
# 10                     0              6          2010             WD
# 11                     0              2          2010            COD
# 12                     0              3          2010             WD
# 13                     0              6          2010             WD
# 14                     0              6          2010             WD
# 15                     0              1          2010            New
# 16                     0              6          2010            New
# 17                     0              6          2010             WD
# 18                     0              2          2010             WD
# 19                     0              6          2010             WD
# 20                     0              6          2010             WD
# 21                     0              4          2010             WD
# 22                     0              1          2010             WD
# 23                     0              1          2010             WD
# 24                     0              6          2010             WD
# 25                     0              4          2010             WD
# 26                     0              1          2010             WD
# 27                     0              5          2010             WD
# 28                     0              4          2010            New
# 29                     0              5          2010             WD
# ...                  ...            ...           ...            ...
# 1429                   0              3          2006             WD
# 1430                   0              4          2006             WD
# 1431                   0             10          2006             WD
# 1432                   0             10          2006             WD
# 1433                   0              4          2006             WD
# 1434                   0              2          2006            New
# 1435                   0             12          2006             WD
# 1436                   0              9          2006             WD
# 1437                   0             10          2006             WD
# 1438                   0              5          2006             WD
# 1439                   0              5          2006             WD
# 1440                   0              3          2006             WD
# 1441                   0             10          2006             WD
# 1442                   0             11          2006            New
# 1443                   0              9          2006            New
# 1444                   0              5          2006             WD
# 1445                   0             11          2006             WD
# 1446                   0              5          2006             WD
# 1447                   0             10          2006             WD
# 1448                   0              3          2006             WD
# 1449                   0              4          2006             WD
# 1450                   0              5          2006             WD
# 1451                   0              5          2006             WD
# 1452                   0             12          2006             WD
# 1453                   0              6          2006             WD
# 1454                   0              6          2006             WD
# 1455                   0              4          2006             WD
# 1456                   0              9          2006             WD
# 1457                 700              7          2006             WD
# 1458                   0             11          2006             WD
#
#       Condición venta
# 0              Normal
# 1              Normal
# 2              Normal
# 3              Normal
# 4              Normal
# 5              Normal
# 6              Normal
# 7              Normal
# 8              Normal
# 9              Normal
# 10             Normal
# 11             Normal
# 12             Normal
# 13             Normal
# 14             Normal
# 15            Partial
# 16            Partial
# 17             Normal
# 18             Normal
# 19             Normal
# 20             Normal
# 21             Normal
# 22             Normal
# 23             Normal
# 24             Normal
# 25             Normal
# 26             Normal
# 27             Normal
# 28            Partial
# 29             Normal
# ...               ...
# 1429           Normal
# 1430           Normal
# 1431          Abnorml
# 1432          Abnorml
# 1433           Normal
# 1434          Partial
# 1435           Normal
# 1436           Normal
# 1437           Normal
# 1438           Normal
# 1439           Normal
# 1440           Alloca
# 1441           Normal
# 1442          Partial
# 1443          Partial
# 1444           Normal
# 1445           Normal
# 1446           Normal
# 1447           Normal
# 1448           Normal
# 1449           Normal
# 1450           Normal
# 1451           Normal
# 1452          Abnorml
# 1453           Normal
# 1454           Normal
# 1455          Abnorml
# 1456          Abnorml
# 1457           Normal
# 1458           Normal
#
# [1459 rows x 80 columns]

# %% [markdown]
# ### Para facilitar el manejo de las variables, las imprimimos

# %%
train.columns
# Out:
# Index(['Id', 'Clasificación', 'Zona', 'Ancho de calle',
#        'Pies cuadrados terreno', 'Pavimento', 'Callejón', 'Relieve',
#        'Geografía del terreno', 'Utilidades', 'Localización', 'Pendiente',
#        'Vecindario', 'Condición 1', 'Condición 2', 'Tipo de vivienda',
#        'Plantas', 'Calidad vivienda', 'Calidad materiales',
#        'Año de construcción', 'Año de reforma', 'Estilo tejado',
#        'Material tejado', 'Primer revestimiento exterior',
#        'Segundo revestimiento exterior', 'Tipo de bloque',
#        'Cantidad bloques pies cuadrados', 'Calidad materiales exterior',
#        'Condición materiales exterior', 'Base', 'Altura sótano',
#        'Condición sótano', 'Puertecita sótano', 'Clasificación sótano zona1',
#        'Pies cuadr. z1 sótano', 'Clasificación sótano zona2',
#        'Pies cuadr. z2 sótano', 'Pies cuadr. sótano sin acabar',
#        'Total pies cuadr. sótano', 'Tipo de calefacción',
#        'Calidad y condición de la calefacción', 'Aire acondicionado',
#        'Sistema eléctrico', 'Pies cuadr. primer piso',
#        'Pies cuadr. segundo piso', 'Pes cuadr. baja calidad',
#        'Pes cuadr. totales (sin garaje)', 'Baños enteros sótano',
#        'Baños a medias sótano', 'Baños enteros por encima',
#        'Baños a medias por encima ', 'Dormitorios por encima',
#        'Cocina por encima', 'Calidad cocina', 'Habitaciones por encima',
#        'Funcionalidad casa', 'Chimeneas', 'Calidad chimeneas',
#        'Tipo de garaje', 'Año construcción garaje', 'Situación garaje',
#        'Coches garaje', 'Pies cuadr. garaje', 'Calidad garaje',
#        'Condición garaje', 'Pavimento entrada coche',
#        'Pies cuadr. cubierta madera', 'Pies cuadr. poche abierto',
#        'Pies cuadr. porcha cerrado', 'Pies cuadr. cerramiento', 'ScreenPorch',
#        'Pies cuadr. piscina', 'Calidad y condición piscina', 'Valla',
#        'Otras características', 'Valor otras caract.', 'Precio mensual',
#        'Precio anual', 'Tipo de venta', 'Condición venta', 'PrecioDeVenta'],
#       dtype='object')

# %% [markdown]
#  # <div align="center">2. Visualizamos las propiedades de nuestra variable objetivo</div>

# %%
train['PrecioDeVenta'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: PrecioDeVenta, dtype: float64

# %%
sns.distplot(train['PrecioDeVenta']);

# %%
#oblicuidad
print("Skewness: %f" % train['PrecioDeVenta'].skew())
#Curtosis
print("Kurtosis: %f" % train['PrecioDeVenta'].kurt())
# Out:
# Skewness: 1.882876
# Kurtosis: 6.536282

# %% [markdown]
#  # <div align="center">3.Correlaciones</div>

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# Create correlation matrix
corr_matrix = train.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Encontramos variables cuya correlación sea mayor a 0.90
to_drop = [column for column in upper.columns if any(upper[column] > 0.80)]
print(to_drop)
# Drop features 
train.drop(train[to_drop], axis=1,inplace = True)
# Out:
# ['Pies cuadr. primer piso', 'Habitaciones por encima', 'Año construcción garaje', 'Pies cuadr. garaje']

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
train.shape
# Out:
# (1460, 77)

# %% [markdown]
#  # <div align="center">4.Outliers</div>

# %% [markdown]
# ### Los outliers son puntos que destacan por separarse mucho de la linea de regresión
# ### En este puntos buscaremos si hay alguno que pueda influir en nuestro resultado y borraremos el dato por completo
# ### Lo primero que haremos sera hacer una matriz de correlación, pero esta vez imprimiremos solo los 8 valores que mayor correlación tengan con PrecioDeVenta, ya que son las variables que nos importaran a la hora de buscar Outliers, ya que si la correlación con PrecioDeVenta es baja, no encontraremos ninguno, debido a que todos los puntos estaran muy dispersos

# %%
#Variables con correlacion alta con PrecioDeVenta
k = 8 
cols = corrmat.nlargest(k, 'PrecioDeVenta')['PrecioDeVenta'].index
cm = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# ### A continuación haremos la matriz de las gráficas de puntos de las variables que vimos que mayor correlación tenian con PrecioDeVenta

# %%
sns.set()
cols = ['PrecioDeVenta', 'Calidad vivienda', 'Pes cuadr. totales (sin garaje)', 'Coches garaje', 'Total pies cuadr. sótano', 'Baños enteros por encima', 'Año de construcción','Año de reforma']
sns.pairplot(train[cols], size = 2.5)
plt.show();

# %% [markdown]
# ### Encontramos dos variables que tienen una muy fuerte correlación con precio de venta, pero a su vez tienen algunos puntos que no estan cerca de la línea de regresión, estos son Pes cuadr. totales (sin garaje) y Total pies cuadr. sótano.
# ### Ampliemos las gráficas a ver que averiguamos

# %%
var = 'Pes cuadr. totales (sin garaje)'
data = pd.concat([train['PrecioDeVenta'], train[var]], axis=1)
data.plot.scatter(x=var, y='PrecioDeVenta', ylim=(0,800000));

# %% [markdown]
# ### Encontramos dos Outliers en esta grafica, y procedemos a borrarlos, podriamos ir a la tabla y buscar la ID de los datos para asi borrarlos, pero mejor aun, podemos automatizar este proceso, poniendo que sección de la tabla queremos borrar, en este caso, que el eje x sea mayor a 4000 y  el eje Y menos a 300000

# %%
train = train.drop(train[(train['Pes cuadr. totales (sin garaje)']>4000) & (train['PrecioDeVenta']<300000)].index)
var = 'Pes cuadr. totales (sin garaje)'
data = pd.concat([train['PrecioDeVenta'], train[var]], axis=1)
data.plot.scatter(x=var, y='PrecioDeVenta', ylim=(0,800000));

# %% [markdown]
# ### La otra variable que queremos estudiar es 'Total pies cuadr. sótano'

# %%
var = 'Total pies cuadr. sótano'
data = pd.concat([train['PrecioDeVenta'], train[var]], axis=1)
data.plot.scatter(x=var, y='PrecioDeVenta', ylim=(0,800000));

# %% [markdown]
# ### Vemos que el Outlier que encontrabamos con anterioridad en la matriz, ya no esta, esto se debe a que coincidia con el outlier que borramos de la anterior variable, vemos que hay un par de puntos un poco dispersos, pero no consideramos que sea suficiente como para borrarlos.

# %% [markdown]
#  # <div align="center">5.Limpieza de los datos</div>

# %% [markdown]
# ### Borramos la columna ID ya que no nos sirve para el modelo de predicción, aun y asi la guardamos a parte

# %%
#Numero de columnas
print("Tamaño del train.csv : {} ".format(train.shape))
print("Tamaño del test.csv: {} ".format(test.shape))

#Guardamos la columna de ID
train_ID = train['Id']
test_ID = test['Id']

#Borramos la columna id ya que no sirve para hacer predicciones
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

#checkeamos el tamño tras quitar la columna ID
print("\nTamaño del train.csv tras borrar el ID : {} ".format(train.shape)) 
print("Tamaño del test.csv tras borrar el ID : {} ".format(test.shape))
# Out:
# Tamaño del train.csv : (1458, 77)
# Tamaño del test.csv: (1459, 80)
#
# Tamaño del train.csv tras borrar el ID : (1458, 76)
# Tamaño del test.csv tras borrar el ID : (1459, 79)

# %% [markdown]
# ### Para proceder a la limpieza de los datos, lo primero que haremos sera concatenar el dataframe train con el test, para limpiar las dos tablas a la vez, además deberemos de borrar la columna de 'PrecioDeVenta' de esta concatenación, ya que el dataframe Test no la contiene.

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
y_train = train.PrecioDeVenta.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['PrecioDeVenta'], axis=1, inplace=True)
print("all_data size is : {}".format(all_data.shape))
# Out:
# all_data size is : (2917, 79)

# %% [markdown]
# ### A continuación veremos la cantidad de datos que faltan en cada una de las variables

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(20)
# Out:
#                              Missing Ratio
# Calidad y condición piscina      99.691464
# Otras características            96.400411
# Callejón                         93.212204
# Valla                            80.425094
# Año construcción garaje          52.656839
# Pies cuadr. garaje               50.017141
# Habitaciones por encima          49.982859
# Pies cuadr. primer piso          49.982859
# Calidad chimeneas                48.680151
# Ancho de calle                   16.660953
# Calidad garaje                    5.450806
# Situación garaje                  5.450806
# Condición garaje                  5.450806
# Tipo de garaje                    5.382242
# Puertecita sótano                 2.811107
# Condición sótano                  2.811107
# Altura sótano                     2.776826
# Clasificación sótano zona2        2.742544
# Clasificación sótano zona1        2.708262
# Tipo de bloque                    0.822763

# %%
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
# Out:
# Text(0.5,1,'Percent missing data by feature')

# %%
#NA significa sin piscina por lo que lo cambiamos por None
all_data["Calidad y condición piscina"] = all_data["Calidad y condición piscina"].fillna("None")

# %%
#NA significa que no tiene características extras por lo que lo cambiamos por None
all_data["Otras características"] = all_data["Otras características"].fillna("None")

# %%
#NA significa que no tiene acceso por callejon por lo que lo cambiamos por None
all_data["Callejón"] = all_data["Callejón"].fillna("None")

# %%
#NA significa que no tiene valla por lo que lo cambiamos por None
all_data["Valla"] = all_data["Valla"].fillna("None")

# %%
#NA significa que no tiene chimenea por lo que lo cambiamos por None
all_data["Calidad chimeneas"] = all_data["Calidad chimeneas"].fillna("None")

# %%
#No sabemos el dato, pero si que sabemos el ancho de la calle de otras casas del barrio, por lo que usaremos la mediana
#de ancho de la calle del barrio para estimar el ancho de la calle
all_data["Ancho de calle"] = all_data.groupby("Vecindario")["Ancho de calle"].transform(
    lambda x: x.fillna(x.median()))

# %%
for col in ('Tipo de garaje', 'Condición garaje', 'Calidad garaje', 'Situación garaje'):
    all_data[col] = all_data[col].fillna('None')

# %%
for col in ('Año construcción garaje', 'Pies cuadr. garaje', 'Coches garaje'):
    all_data[col] = all_data[col].fillna(0)

# %%
for col in ('Pies cuadr. z1 sótano', 'Pies cuadr. z2 sótano', 'Pies cuadr. sótano sin acabar','Total pies cuadr. sótano', 'Baños enteros sótano', 'Baños a medias sótano'):
    all_data[col] = all_data[col].fillna(0)

# %%
for col in ('Altura sótano', 'Condición sótano', 'Puertecita sótano', 'Clasificación sótano zona1', 'Clasificación sótano zona2'):
    all_data[col] = all_data[col].fillna('None')

# %%
all_data["Tipo de bloque"] = all_data["Tipo de bloque"].fillna("None")
all_data["Cantidad bloques pies cuadrados"] = all_data["Cantidad bloques pies cuadrados"].fillna(0)

# %%
all_data['Zona'] = all_data['Zona'].fillna(all_data['Zona'].mode()[0])

# %%
#borrar, solo varia en el train
all_data = all_data.drop(['Utilidades'], axis=1)

# %%
#Na-Tipico
all_data["Funcionalidad casa"] = all_data["Funcionalidad casa"].fillna("Typ")

# %%
all_data['Sistema eléctrico'] = all_data['Sistema eléctrico'].fillna(all_data['Sistema eléctrico'].mode()[0])

# %%
#solo 1 NA moda
all_data['Calidad cocina'] = all_data['Calidad cocina'].fillna(all_data['Calidad cocina'].mode()[0])

# %%
all_data['Primer revestimiento exterior'] = all_data['Primer revestimiento exterior'].fillna(all_data['Primer revestimiento exterior'].mode()[0])
all_data['Segundo revestimiento exterior'] = all_data['Segundo revestimiento exterior'].fillna(all_data['Segundo revestimiento exterior'].mode()[0])

# %%
all_data['Tipo de venta'] = all_data['Tipo de venta'].fillna(all_data['Tipo de venta'].mode()[0])

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data
# Out:
#                          Missing Ratio
# Pies cuadr. primer piso      49.982859
# Habitaciones por encima      49.982859

# %% [markdown]
#  # <div align="center">6. Extras</div>

# %%
all_data['Total habitable'] = all_data['Total pies cuadr. sótano'] + all_data['Pies cuadr. primer piso'] + all_data['Pies cuadr. segundo piso']

# %%
sns.distplot(all_data['Total habitable']);
sns.distplot(all_data['Valor otras caract.']);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-f8e3c06cc3c2> in <module>()
# ----> 1 sns.distplot(all_data['Total habitable']);
#       2 sns.distplot(all_data['Valor otras caract.']);
#
# D:\Anaconda\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# D:\Anaconda\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index
from scipy.stats import norm, skew
# Check the skew of all numerical features
skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(10)
# Out:
# Skew in numerical features:
#                                  Skew
# Valor otras caract.         21.939672
# Pies cuadr. piscina         17.688664
# Pies cuadrados terreno      13.109495
# Pes cuadr. baja calidad     12.084539
# Pies cuadr. cerramiento     11.372080
# Cocina por encima            4.300550
# Pies cuadr. z2 sótano        4.144503
# Pies cuadr. porcha cerrado   4.002344
# ScreenPorch                  3.945101
# Baños a medias sótano        3.929996

# %%
sns.distplot(all_data['Pies cuadr. piscina']);
print("Skewness: %f" % train['Pies cuadr. piscina'].skew())
# Out:
# Skewness: 15.948945

# %%
skewness = skewness[abs(skewness) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(skewness.shape[0]))

from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    #all_data[feat] += 1
    all_data[feat] = boxcox1p(all_data[feat], lam)
# Out:
# There are 37 skewed numerical features to Box Cox transform

# %%
sns.distplot(all_data['Pies cuadr. piscina']);


print("Skewness: %f" % train['Pies cuadr. piscina'].skew())
# Out:
# Skewness: 15.948945

# %%
print("Skewness: %f" % all_data['Año construcción garaje'].skew())
# Out:
# Skewness: 0.106528
